# %% [markdown]
# pullrequest
# 1. fork
# 2. clone vscode(3 кружочка слева)
# 3. edit code
# 4.commit
# 5.push
# 6.pullrequest в github

# %% [markdown]
# git - это контроль версий, он локальный.

# %% [markdown]
#  git config --global user.email "romamuhachev6@gmail.com"
#   git config --global user.name "Gorrok"
